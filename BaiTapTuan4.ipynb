# %%
#W4A1c SumOfNumbers
ans = 0
for i in range (1000):
    ans += i
print(ans)
# Out:
# 499500

# %%
#W4A2 PrimeNumber

def check(x):
    i = 2
    while (i * i <= ans):
        if ans % i == 0:
            return False
        i += 1
    return True

ans = int(0)
while (ans <= 0):
    ans = int(input())

if check(ans) == True:
    print("La so nguyen to")
else:
    print("Khong La So Nguyen To")
# Out:
# Khong La So Nguyen To

# %%
#W4A4
def Giaithua(x):
    if (x == 1):
        return 1
    return x * Giaithua(x - 1)
i = int(input())
print(Giaithua(i))
# Out:
# 6

# %%
#W4A5 MeaningOfLife

def check(b):
    for i in b:
        if (i == 42):
            return True
    return False

a = []
n = int(input())
for i in range(n):
    x = int(input())
    a.append(x)
if (check(a) == True):
    print("I've found the meaning of life!")
else:
    print("It's a joke!")
# Out:
# I've found the meaning of life!

# %%
#W4A6 SumPrimesInRange


f = [0] * (10 ** 6)
def Sang():
    f[0] = f[1] = 1
    for i in range(2,int(1e7 ** 0.5) + 1):
        if f[i] == 0:
            for j in range(i * i, int(1e7), i):
                f[j] = 1

Sang()
n = int(input())
while True:
    try:
        a, b = map(int, input().split())
    except:
        break
    ans = 0
    for i in range(a, b + 1):
        if (f[i] == 0):
            ans += i
    print(ans)
# Out:
# 17

# %%
#W4A7
n = int(input())
ans = 1
i = 2
while (i * i <= n):
    if n % i == 0:
        while n % i == 0:
            n = n / i
        ans = i
    i += 1
print(max(ans, n))
# Out:
# 3

# %%
#W4A8

def check(x):
    if (x[:len(x) // 2:1] == x[:round(len(x) / 2) - 1:-1]):
        return True
    return False

def Solve(x, step):
    if check(str(x)) == True:
        print(x)
        print(step)
        return
    revx = str(x)[::-1]
    Solve(x + int(revx), step + 1)

n = int(input())
Solve(n, 1)
# Out:
# 1111
# 3

# %%
#W4A9 PerfectSquaresDistinctDigits

def check(x):
    a = [0] * 10
    while (x > 0):
        a[x % 10] += 1
        x //= 10
    for i in a:
        if i >= 2:
            return False
    return True

n = int(input())
i, dem = 1, 0
while (i * i <= n):
    if (check(i * i) == True):
        dem += 1
        print(i * i, end = " ")
    i += 1
if (dem == 0):
    print("No number")
# Out:
# 1 4 9 16 25 36 49 64 81 169 196 256 289 324 361 529 576 625 729 784 841 961 1024 1089 1296 1369 1764 1849 1936 2304 2401 2601 2704 2809 2916 3025 3249 3481 3721 4096 4356 4761 5041 5184 5329 5476 6084 6241 6724 7056 7396 7569 7921 8649 9025 9216 9604 9801

# %%
#W4A10
def CollatzCounter(x):
    step = 0
    while (x != 1):
        if x % 2 == 0:
            x /= 2
        else:
            x = x * 3 + 1
        step += 1
    return step

n = int(input())
a = [0]
ans = 0
for i in range(1, n + 1):
    a.append(CollatzCounter(i))
    ans = max(ans, a[-1])
for index, value in enumerate(a):
    if value == ans:
        print(index, value)
        break
# Out:
# 77031 350

# %%
#4A11
n = int(input())
for i in range(1, n + 1):
    if (n % i == 0 and i % 2 == 0):
        ans += 1
print(ans)

# %%
#4A12
x = int(input())
n = int(input())
for i in range(n):
    x = x + int(x * 0.007)
print(x)
# Out:
# 1014049

# %%
#4A13

def divisorCounter(x):
    res = 0
    for i in range (1, int(x ** 0.5) + 1):
        if x % i == 0:
            res += i
            if (x / i != i):
                res += x / i
    return res

x, y = map(int, input().split())
if divisorCounter(x) - x == y and divisorCounter(y) - y == x:
    print("YES")
else:
    print("NO")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 12
#       9                 res += x / i
#      10     return res
# ---> 12 x, y = map(int, input().split())
#      13 if divisorCounter(x) - x == y and divisorCounter(y) - y == x:
#      14     print("YES")
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
#W4A14 GCD

from math import gcd
m, n = map(int, input().split())
print(gcd(m, n))
# Out:
# 4

# %%
TongCon, TongChan = map(int, input().split())
Chicken, Dog = 0, 0
'''
Chicken + Dog = TongCon
2 * Chicken + 4 * Dong = TongChan

= > Dog = (TongChan - 2 * TongCon) / 2
'''

Dog = (TongChan - 2 * TongCon) / 2
Chicken = TongCon - Dog
if (int(Dog) == Dog and int(Chicken) == Chicken):
    print(int(Dog), int(Chicken))
else:
    print("invalid")
# Out:
# 14.0 22.0
