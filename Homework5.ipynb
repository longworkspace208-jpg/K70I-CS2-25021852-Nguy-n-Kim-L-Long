# %%
#W6A16
Col = int(input())
Row = int(input())

Ans_list = [[]] * (Col + 1)
for i in range(Col):
    t = list(map(int, input().split()))
    Ans_list[i] = t
    print("    ".join(map(str, Ans_list[i])), end = '\n')
# Out:
# 2    4    5    6
# 6    7    8    9
